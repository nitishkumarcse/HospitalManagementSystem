# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/HospitalManagementSystem/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

greatest = 0

while num > 0:
    digit = num % 10       # get last digit

    if digit > greatest:
        greatest = digit

    num = num // 10        # remove last digit

print("Greatest digit is:", greatest)
